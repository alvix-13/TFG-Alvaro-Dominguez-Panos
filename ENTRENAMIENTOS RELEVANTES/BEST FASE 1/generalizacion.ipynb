# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
path = "data_test.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["TimeStamp", "label"], axis=1)
y_df = df["label"]

# %% [markdown]
# # RandomForest

# %%
modelo_final = pickle.load(open('MODELOS/modelo_RF.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.20      0.30        30
#            1       0.00      0.00      1.00        30
#            2       0.15      0.23      0.18        31
#            3       1.00      0.30      0.46        30
#            4       0.33      0.50      0.40        30
#            5       0.41      0.90      0.56        31
#            6       0.80      0.53      0.64        30
#
#     accuracy                           0.38       212
#    macro avg       0.47      0.38      0.51       212
# weighted avg       0.47      0.38      0.50       212

# %%
forest_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {forest_accuracy}")
# Out:
# El valor de accuracy: 0.38207547169811323

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LogisticRegression

# %%
modelo_final = pickle.load(open('modelo_LR.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.10      0.15        30
#            1       0.00      0.00      1.00        30
#            2       0.43      0.74      0.54        31
#            3       0.25      0.57      0.35        30
#            4       1.00      0.00      0.00        30
#            5       0.91      0.94      0.92        31
#            6       1.00      0.83      0.91        30
#
#     accuracy                           0.46       212
#    macro avg       0.55      0.45      0.55       212
# weighted avg       0.55      0.46      0.55       212

# %%
logistic_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {logistic_accuracy}")
# Out:
# El valor de accuracy: 0.45754716981132076

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # HistGradientBoosting

# %%
modelo_final = pickle.load(open('MODELOS/modelo_HIST.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.37      0.54        30
#            1       0.00      0.00      1.00        30
#            2       0.29      0.52      0.37        31
#            3       0.50      0.07      0.12        30
#            4       0.30      0.53      0.38        30
#            5       0.48      0.87      0.62        31
#            6       0.94      0.50      0.65        30
#
#     accuracy                           0.41       212
#    macro avg       0.50      0.41      0.53       212
# weighted avg       0.50      0.41      0.52       212

# %%
hist_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {hist_accuracy}")
# Out:
# El valor de accuracy: 0.41037735849056606

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # XGBoost

# %%
modelo_final = pickle.load(open('MODELOS/modelo_XGB.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      1.00        30
#            1       0.00      0.00      1.00        30
#            2       0.25      0.52      0.34        31
#            3       0.92      0.37      0.52        30
#            4       0.43      0.63      0.51        30
#            5       0.41      0.94      0.57        31
#            6       0.94      0.53      0.68        30
#
#     accuracy                           0.43       212
#    macro avg       0.42      0.43      0.66       212
# weighted avg       0.42      0.43      0.66       212

# %%
xgb_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {xgb_accuracy}")
# Out:
# El valor de accuracy: 0.42924528301886794

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LightGBM

# %%
modelo_final = pickle.load(open('MODELOS/modelo_LGBMC.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.40      0.56        30
#            1       0.07      0.03      0.05        30
#            2       0.31      0.71      0.44        31
#            3       1.00      0.03      0.06        30
#            4       0.41      0.53      0.46        30
#            5       0.50      0.90      0.64        31
#            6       0.79      0.50      0.61        30
#
#     accuracy                           0.45       212
#    macro avg       0.57      0.44      0.40       212
# weighted avg       0.57      0.45      0.40       212

# %%
light_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {light_accuracy}")
# Out:
# El valor de accuracy: 0.4481132075471698

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
modelo_final = pickle.load(open('MODELOS/modelo_SVM.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.34        30
#            1       0.08      0.07      0.07        30
#            2       0.32      0.65      0.43        31
#            3       1.00      0.23      0.38        30
#            4       0.70      0.23      0.35        30
#            5       0.94      0.94      0.94        31
#            6       0.83      0.50      0.62        30
#
#     accuracy                           0.45       212
#    macro avg       0.59      0.44      0.45       212
# weighted avg       0.59      0.45      0.45       212

# %%
svm_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {svm_accuracy}")
# Out:
# El valor de accuracy: 0.4481132075471698

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SGD

# %%
modelo_final = pickle.load(open('MODELOS/modelo_SGD.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.20      0.27        30
#            1       0.35      0.47      0.40        30
#            2       0.15      0.42      0.23        31
#            3       0.31      0.13      0.19        30
#            4       1.00      0.00      0.00        30
#            5       0.64      0.94      0.76        31
#            6       0.88      0.47      0.61        30
#
#     accuracy                           0.38       212
#    macro avg       0.54      0.37      0.35       212
# weighted avg       0.54      0.38      0.35       212

# %%
sgd_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {sgd_accuracy}")
# Out:
# El valor de accuracy: 0.37735849056603776

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['RandomForest', 'LogisticRegression', 'HistGradientBoosting', 'XGBoost', 'LightGBM', 'SVM', 'SGD'],
                    'valores accuracy': [forest_accuracy, logistic_accuracy, hist_accuracy, xgb_accuracy, light_accuracy, svm_accuracy, sgd_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Accuracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)
