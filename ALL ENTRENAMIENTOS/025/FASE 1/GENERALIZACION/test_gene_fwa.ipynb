# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
path = "data_test_fwa.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["TimeStamp", "label"], axis=1)
y_df = df["label"]

# %% [markdown]
# # RandomForest

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_RF.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      1.00        30
#            1       0.20      0.07      0.10        30
#            2       0.44      0.52      0.48        31
#            3       0.44      0.27      0.33        30
#            4       0.18      0.07      0.10        30
#            5       0.34      0.97      0.51        31
#            6       0.60      0.93      0.73        30
#
#     accuracy                           0.41       212
#    macro avg       0.32      0.40      0.46       212
# weighted avg       0.32      0.41      0.46       212

# %%
forest_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {forest_accuracy}")
# Out:
# El valor de accuracy: 0.4056603773584906

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LogisticRegression

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_LR.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      1.00        30
#            1       0.00      0.00      1.00        30
#            2       0.00      0.00      1.00        31
#            3       0.25      0.10      0.14        30
#            4       1.00      0.00      0.00        30
#            5       0.27      0.90      0.41        31
#            6       0.35      0.97      0.51        30
#
#     accuracy                           0.28       212
#    macro avg       0.27      0.28      0.58       212
# weighted avg       0.27      0.28      0.58       212

# %%
logistic_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {logistic_accuracy}")
# Out:
# El valor de accuracy: 0.2830188679245283

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # HistGradientBoosting

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_HIST.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       0.20      0.30      0.24        30
#            2       0.35      0.81      0.49        31
#            3       0.56      0.50      0.53        30
#            4       1.00      0.00      0.00        30
#            5       0.88      0.90      0.89        31
#            6       0.42      0.50      0.45        30
#
#     accuracy                           0.43       212
#    macro avg       0.63      0.43      0.37       212
# weighted avg       0.63      0.43      0.37       212

# %%
hist_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {hist_accuracy}")
# Out:
# El valor de accuracy: 0.4339622641509434

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # XGBoost

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_XGB.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       0.00      0.00      1.00        30
#            2       0.36      0.68      0.47        31
#            3       0.76      0.43      0.55        30
#            4       1.00      0.07      0.12        30
#            5       0.40      0.87      0.55        31
#            6       0.33      0.50      0.39        30
#
#     accuracy                           0.37       212
#    macro avg       0.55      0.36      0.44       212
# weighted avg       0.55      0.37      0.44       212

# %%
xgb_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {xgb_accuracy}")
# Out:
# El valor de accuracy: 0.36792452830188677

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LightGBM

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_LGBMC.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       0.00      0.00      1.00        30
#            2       0.29      0.35      0.32        31
#            3       0.42      0.50      0.45        30
#            4       0.19      0.17      0.18        30
#            5       0.45      0.90      0.60        31
#            6       0.34      0.50      0.41        30
#
#     accuracy                           0.35       212
#    macro avg       0.38      0.35      0.42       212
# weighted avg       0.38      0.35      0.42       212

# %%
light_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {light_accuracy}")
# Out:
# El valor de accuracy: 0.3490566037735849

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_SVM.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       0.00      0.00      1.00        30
#            2       0.36      0.29      0.32        31
#            3       0.36      0.13      0.20        30
#            4       0.10      0.07      0.08        30
#            5       0.97      0.94      0.95        31
#            6       0.14      0.53      0.22        30
#
#     accuracy                           0.28       212
#    macro avg       0.42      0.28      0.40       212
# weighted avg       0.42      0.28      0.40       212

# %%
svm_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {svm_accuracy}")
# Out:
# El valor de accuracy: 0.2830188679245283

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SGD

# %%
modelo_final = pickle.load(open('../MODELOS/FWA/modelo_SGD.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       1.00      0.00      0.00        30
#            2       1.00      0.00      0.00        31
#            3       0.18      1.00      0.30        30
#            4       1.00      0.00      0.00        30
#            5       0.69      0.94      0.79        31
#            6       1.00      0.00      0.00        30
#
#     accuracy                           0.28       212
#    macro avg       0.84      0.28      0.16       212
# weighted avg       0.84      0.28      0.16       212

# %%
sgd_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {sgd_accuracy}")
# Out:
# El valor de accuracy: 0.2783018867924528

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['RandomForest', 'LogisticRegression', 'HistGradientBoosting', 'XGBoost', 'LightGBM', 'SVM', 'SGD'],
                    'valores accuracy': [forest_accuracy, logistic_accuracy, hist_accuracy, xgb_accuracy, light_accuracy, svm_accuracy, sgd_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Accuracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)
