# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # GENERALIZACIÓN ALL

# %%
path = "data_test.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["label", "TimeStamp"], axis=1)
y_df = df["label"]

# %% [markdown]
# ## LogisticRegression

# %%
modelo_final = pickle.load(open('modelo_LR.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.30      0.28        30
#            1       0.29      0.20      0.24        30
#            2       0.00      0.00      1.00        31
#            3       0.32      0.33      0.33        30
#            4       1.00      0.00      0.00        30
#            5       0.33      1.00      0.49        31
#            6       0.97      0.93      0.95        30
#
#     accuracy                           0.40       212
#    macro avg       0.45      0.40      0.47       212
# weighted avg       0.45      0.40      0.47       212

# %%
logistic_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {logistic_accuracy}")
# Out:
# El valor de accuracy: 0.39622641509433965

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# ## Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['LogisticRegression'],
                    'valores accuracy': [ logistic_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Acurracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)

# %% [markdown]
# # GENERALIZACIÓN 4 GESTOS PALMA

# %%
path = "data_test_4G.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["label", "TimeStamp"], axis=1)
y_df = df["label"]

# %% [markdown]
# ## XGBoost

# %%
modelo_final = pickle.load(open('modelo_XGB4.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.53      0.68        30
#            1       0.40      0.55      0.47        31
#            2       0.63      0.94      0.75        31
#            3       1.00      0.57      0.72        30
#
#     accuracy                           0.65       122
#    macro avg       0.74      0.65      0.66       122
# weighted avg       0.74      0.65      0.66       122

# %%
xgb_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {xgb_accuracy}")
# Out:
# El valor de accuracy: 0.6475409836065574

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# ## Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['XGBoost'],
                    'valores accuracy': [xgb_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Acurracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)
