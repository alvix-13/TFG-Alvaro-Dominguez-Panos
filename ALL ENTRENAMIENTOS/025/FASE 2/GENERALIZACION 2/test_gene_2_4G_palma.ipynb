# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plts
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # GENERALIZACIÓN 4 GESTOS PALMA

# %%
path = "data_test_4G_palma.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["label", "TimeStamp"], axis=1)
y_df = df["label"]

# %% [markdown]
# # RandomForest

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_RF.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       0.35      0.52      0.42        31
#            2       0.48      0.94      0.63        31
#            3       1.00      0.50      0.67        30
#
#     accuracy                           0.49       122
#    macro avg       0.71      0.49      0.43       122
# weighted avg       0.70      0.49      0.43       122

# %%
forest_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {forest_accuracy}")
# Out:
# El valor de accuracy: 0.4918032786885246

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LogisticRegression

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_LR.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.47      0.62        30
#            1       0.94      0.48      0.64        31
#            2       0.49      1.00      0.66        31
#            3       1.00      0.93      0.97        30
#
#     accuracy                           0.72       122
#    macro avg       0.84      0.72      0.72       122
# weighted avg       0.84      0.72      0.72       122

# %%
logistic_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {logistic_accuracy}")
# Out:
# El valor de accuracy: 0.7213114754098361

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # HistGradientBoosting

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_HIST.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.37      0.50        30
#            1       0.34      0.45      0.39        31
#            2       0.58      0.90      0.71        31
#            3       0.84      0.53      0.65        30
#
#     accuracy                           0.57       122
#    macro avg       0.64      0.56      0.56       122
# weighted avg       0.64      0.57      0.56       122

# %%
hist_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {hist_accuracy}")
# Out:
# El valor de accuracy: 0.5655737704918032

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # XGBoost

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_XGB.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        30
#            1       0.60      0.48      0.54        31
#            2       0.57      0.90      0.70        31
#            3       1.00      0.90      0.95        30
#
#     accuracy                           0.72       122
#    macro avg       0.76      0.72      0.72       122
# weighted avg       0.75      0.72      0.72       122

# %%
xgb_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {xgb_accuracy}")
# Out:
# El valor de accuracy: 0.7213114754098361

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LightGBM

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_LGBMC.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.47      0.55        30
#            1       0.41      0.52      0.46        31
#            2       0.62      0.90      0.74        31
#            3       0.94      0.53      0.68        30
#
#     accuracy                           0.61       122
#    macro avg       0.66      0.60      0.61       122
# weighted avg       0.66      0.61      0.61       122

# %%
light_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {light_accuracy}")
# Out:
# El valor de accuracy: 0.6065573770491803

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_SVM.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.63      0.69        30
#            1       0.71      0.48      0.58        31
#            2       0.55      0.94      0.69        31
#            3       1.00      0.77      0.87        30
#
#     accuracy                           0.70       122
#    macro avg       0.76      0.70      0.71       122
# weighted avg       0.75      0.70      0.71       122

# %%
svm_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {svm_accuracy}")
# Out:
# El valor de accuracy: 0.7049180327868853

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SGD

# %%
modelo_final = pickle.load(open('../MODELOS 2/4 GESTOS PALMA/modelo_SGD.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.57        30
#            1       1.00      0.00      0.00        31
#            2       0.46      1.00      0.63        31
#            3       0.94      0.97      0.95        30
#
#     accuracy                           0.61       122
#    macro avg       0.76      0.62      0.54       122
# weighted avg       0.76      0.61      0.53       122

# %%
sgd_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {sgd_accuracy}")
# Out:
# El valor de accuracy: 0.6147540983606558

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['RandomForest', 'LogisticRegression', 'HistGradientBoosting', 'XGBoost', 'LightGBM', 'SVM', 'SGD'],
                    'valores accuracy': [forest_accuracy, logistic_accuracy, hist_accuracy, xgb_accuracy, light_accuracy, svm_accuracy, sgd_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Accuracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)
