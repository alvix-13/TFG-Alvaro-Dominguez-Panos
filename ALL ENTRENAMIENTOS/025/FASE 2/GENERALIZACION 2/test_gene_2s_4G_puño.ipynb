# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # GENERALIZACIÓN 4 GESTOS PUÑO

# %%
path = "data_test_4G_puño.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["label", "TimeStamp"], axis=1)
y_df = df["label"]

# %% [markdown]
# # RandomForest

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_RF.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      1.00        30
#            1       0.28      0.33      0.30        30
#            2       0.49      0.97      0.65        31
#            3       0.70      0.53      0.60        30
#
#     accuracy                           0.46       121
#    macro avg       0.37      0.46      0.64       121
# weighted avg       0.37      0.46      0.64       121

# %%
forest_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {forest_accuracy}")
# Out:
# El valor de accuracy: 0.4628099173553719

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LogisticRegression

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_LR.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.87      0.75        30
#            1       0.61      0.47      0.53        30
#            2       0.97      0.94      0.95        31
#            3       0.83      0.80      0.81        30
#
#     accuracy                           0.77       121
#    macro avg       0.77      0.77      0.76       121
# weighted avg       0.77      0.77      0.76       121

# %%
logistic_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {logistic_accuracy}")
# Out:
# El valor de accuracy: 0.768595041322314

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # HistGradientBoosting

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_HIST.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      1.00        30
#            1       0.26      0.33      0.29        30
#            2       0.55      0.90      0.68        31
#            3       0.54      0.50      0.52        30
#
#     accuracy                           0.44       121
#    macro avg       0.34      0.43      0.62       121
# weighted avg       0.34      0.44      0.62       121

# %%
hist_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {hist_accuracy}")
# Out:
# El valor de accuracy: 0.4380165289256198

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # XGBoost

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_XGB.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.27      0.38        30
#            1       0.35      0.53      0.42        30
#            2       0.58      0.94      0.72        31
#            3       1.00      0.43      0.60        30
#
#     accuracy                           0.55       121
#    macro avg       0.65      0.54      0.53       121
# weighted avg       0.65      0.55      0.53       121

# %%
xgb_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {xgb_accuracy}")
# Out:
# El valor de accuracy: 0.5454545454545454

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LightGBM

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_LGBMC.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      1.00        30
#            1       0.37      0.47      0.41        30
#            2       0.46      0.90      0.61        31
#            3       0.79      0.50      0.61        30
#
#     accuracy                           0.47       121
#    macro avg       0.40      0.47      0.66       121
# weighted avg       0.40      0.47      0.66       121

# %%
light_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {light_accuracy}")
# Out:
# El valor de accuracy: 0.47107438016528924

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_SVM.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.93      0.67        30
#            1       0.60      0.10      0.17        30
#            2       0.94      0.94      0.94        31
#            3       0.58      0.60      0.59        30
#
#     accuracy                           0.64       121
#    macro avg       0.66      0.64      0.59       121
# weighted avg       0.66      0.64      0.59       121

# %%
svm_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {svm_accuracy}")
# Out:
# El valor de accuracy: 0.6446280991735537

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SGD

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/4 GESTOS PUÑO/modelo_SGD.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.27      0.41        30
#            1       0.32      0.97      0.48        30
#            2       1.00      0.68      0.81        31
#            3       1.00      0.00      0.00        30
#
#     accuracy                           0.48       121
#    macro avg       0.80      0.48      0.42       121
# weighted avg       0.80      0.48      0.43       121

# %%
sgd_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {sgd_accuracy}")
# Out:
# El valor de accuracy: 0.4793388429752066

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['RandomForest', 'LogisticRegression', 'HistGradientBoosting', 'XGBoost', 'LightGBM', 'SVM', 'SGD'],
                    'valores accuracy': [forest_accuracy, logistic_accuracy, hist_accuracy, xgb_accuracy, light_accuracy, svm_accuracy, sgd_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Accuracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)
