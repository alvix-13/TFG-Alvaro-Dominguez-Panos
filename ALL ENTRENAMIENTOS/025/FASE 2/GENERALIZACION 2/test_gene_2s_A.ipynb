# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # GENERALIZACIÓN SIN ACELEROMETRO + SHUFFLE

# %%
path = "data_test.csv"

df = pd.read_csv(path)

# %%
df_f = df.drop(["label", "TimeStamp", "AccX", "AccY", "AccZ"], axis=1)
y_df = df["label"]

# %% [markdown]
# # RandomForest

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_RF.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.37      0.43        30
#            1       0.09      0.03      0.05        30
#            2       1.00      0.19      0.32        31
#            3       1.00      0.00      0.00        30
#            4       0.27      0.47      0.35        30
#            5       0.47      0.23      0.30        31
#            6       0.17      0.60      0.26        30
#
#     accuracy                           0.27       212
#    macro avg       0.50      0.27      0.25       212
# weighted avg       0.51      0.27      0.25       212

# %%
forest_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {forest_accuracy}")
# Out:
# El valor de accuracy: 0.2688679245283019

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LogisticRegression

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_LR.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.57      0.52        30
#            1       0.18      0.10      0.13        30
#            2       1.00      0.00      0.00        31
#            3       0.40      0.13      0.20        30
#            4       1.00      0.00      0.00        30
#            5       0.26      0.32      0.29        31
#            6       0.21      0.77      0.33        30
#
#     accuracy                           0.27       212
#    macro avg       0.50      0.27      0.21       212
# weighted avg       0.50      0.27      0.21       212

# %%
logistic_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {logistic_accuracy}")
# Out:
# El valor de accuracy: 0.2688679245283019

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # HistGradientBoosting

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_HIST.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.40      0.51        30
#            1       0.60      0.20      0.30        30
#            2       1.00      0.16      0.28        31
#            3       1.00      0.00      0.00        30
#            4       0.27      0.50      0.35        30
#            5       0.50      0.39      0.44        31
#            6       0.15      0.50      0.23        30
#
#     accuracy                           0.31       212
#    macro avg       0.60      0.31      0.30       212
# weighted avg       0.60      0.31      0.30       212

# %%
hist_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {hist_accuracy}")
# Out:
# El valor de accuracy: 0.30660377358490565

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # XGBoost

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_XGB.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.27      0.37        30
#            1       0.00      0.00      1.00        30
#            2       0.89      0.26      0.40        31
#            3       1.00      0.00      0.00        30
#            4       0.29      0.67      0.40        30
#            5       0.59      0.42      0.49        31
#            6       0.17      0.57      0.27        30
#
#     accuracy                           0.31       212
#    macro avg       0.51      0.31      0.42       212
# weighted avg       0.51      0.31      0.42       212

# %%
xgb_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {xgb_accuracy}")
# Out:
# El valor de accuracy: 0.3113207547169811

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # LightGBM

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_LGBMC.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.20      0.30        30
#            1       1.00      0.00      0.00        30
#            2       1.00      0.00      0.00        31
#            3       1.00      0.00      0.00        30
#            4       0.20      0.77      0.32        30
#            5       0.57      0.13      0.21        31
#            6       0.19      0.50      0.27        30
#
#     accuracy                           0.23       212
#    macro avg       0.65      0.23      0.16       212
# weighted avg       0.65      0.23      0.16       212

# %%
light_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {light_accuracy}")
# Out:
# El valor de accuracy: 0.22641509433962265

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_SVM.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.15      0.53      0.23        30
#            1       0.00      0.00      1.00        30
#            2       0.50      0.06      0.11        31
#            3       0.19      0.33      0.24        30
#            4       0.60      0.10      0.17        30
#            5       0.45      0.16      0.24        31
#            6       0.31      0.30      0.31        30
#
#     accuracy                           0.21       212
#    macro avg       0.31      0.21      0.33       212
# weighted avg       0.32      0.21      0.33       212

# %%
svm_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {svm_accuracy}")
# Out:
# El valor de accuracy: 0.21226415094339623

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # SGD

# %%
modelo_final = pickle.load(open('../MODELOS 2 S/NO AC/modelo_SGD.pkl','rb'))

# %%
predicciones = modelo_final.predict(df_f)

# %%
y_test_numeric = np.array(y_df)
predicciones_numeric = np.array(predicciones)

# %%
print(classification_report(y_df, predicciones, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00        30
#            1       0.15      0.40      0.22        30
#            2       1.00      0.00      0.00        31
#            3       0.15      0.40      0.21        30
#            4       1.00      0.00      0.00        30
#            5       1.00      0.13      0.23        31
#            6       0.17      0.27      0.21        30
#
#     accuracy                           0.17       212
#    macro avg       0.64      0.17      0.12       212
# weighted avg       0.64      0.17      0.12       212

# %%
sgd_accuracy = accuracy_score(y_df, predicciones)

print(f"El valor de accuracy: {sgd_accuracy}")
# Out:
# El valor de accuracy: 0.16981132075471697

# %%
cm = confusion_matrix(y_df, predicciones)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_df))
disp.plot()
plt.show()

# %% [markdown]
# # Comparación Modelos

# %%
df_comparacion = pd.DataFrame({
                    'estimador': ['RandomForest', 'LogisticRegression', 'HistGradientBoosting', 'XGBoost', 'LightGBM', 'SVM', 'SGD'],
                    'valores accuracy': [forest_accuracy, logistic_accuracy, hist_accuracy, xgb_accuracy, light_accuracy, svm_accuracy, sgd_accuracy]
                 })

fig, ax = plt.subplots(figsize=(18, 9))
df_comparacion.set_index('estimador').plot(kind='barh', ax=ax)
ax.set_xlabel('Accuracy')
ax.set_ylabel('Estimador')
ax.set_title('Comparación de clasificadores');

for i, v in enumerate(df_comparacion['valores accuracy']):
    ax.annotate(str(round(v, 3)), xy=(v, i), va='center', ha='left', fontsize=10)
